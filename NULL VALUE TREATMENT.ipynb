# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_14 = pd.read_csv('2014_Financial_Data.csv')
df_15 = pd.read_csv('2015_Financial_Data.csv')
df_16 = pd.read_csv('2016_Financial_Data.csv')
df_17 = pd.read_csv('2017_Financial_Data.csv')
df_18 = pd.read_csv('2018_Financial_Data.csv')

# %%
df_14
# Out:
#      Unnamed: 0       Revenue  Revenue Growth  Cost of Revenue  Gross Profit  \
# 0            PG  7.440100e+10         -0.0713     3.903000e+10  3.537100e+10
# 1          VIPS  3.734148e+09          1.1737     2.805625e+09  9.285226e+08
# 2            KR  9.837500e+10          0.0182     7.813800e+10  2.023700e+10
# 3           RAD  2.552641e+10          0.0053     1.820268e+10  7.323734e+09
# 4           GIS  1.790960e+10          0.0076     1.153980e+10  6.369800e+09
# ...         ...           ...             ...              ...           ...
# 3803       TSRI  4.952987e+07          0.1028     4.125164e+07  8.278229e+06
# 3804       TZOO  1.532400e+08         -0.1019     1.917400e+07  1.340660e+08
# 3805      USATP  4.200000e+07             NaN     2.700000e+07  1.500000e+07
# 3806       WSTG  3.407580e+08          0.1344     3.159480e+08  2.481000e+07
# 3807        WTT  4.033737e+07          0.1925     2.129368e+07  1.904369e+07
#
# ...

# %%
df_15
# Out:
#      Unnamed: 0       Revenue  Revenue Growth  Cost of Revenue  Gross Profit  \
# 0            PG  7.074900e+10         -0.0491     3.705600e+10  3.369300e+10
# 1          VIPS  6.193685e+09          0.6587     4.669038e+09  1.524648e+09
# 2            KR  1.084650e+11          0.1026     8.551200e+10  2.295300e+10
# 3           RAD  2.652838e+10          0.0393     1.895164e+10  7.576732e+09
# 4           GIS  1.763030e+10         -0.0156     1.168110e+10  5.949200e+09
# ...         ...           ...             ...              ...           ...
# 4115       TSRI  5.740290e+07          0.1590     4.808743e+07  9.315468e+06
# 4116       TZOO  1.239610e+08         -0.1911     1.814800e+07  1.058130e+08
# 4117      USATP  5.800000e+07             NaN     4.100000e+07  1.700000e+07
# 4118       WSTG  3.820900e+08          0.1213     3.555170e+08  2.657300e+07
# 4119        WTT  3.310911e+07         -0.1792     1.828123e+07  1.482787e+07
#
# ...

# %%
df1 = pd.concat([df_14,df_15,df_16,df_17,df_18])

# %%
df1.shape
# Out:
# (22077, 229)

# %%
df14 = df_14.sort_index()
df15 = df_15.sort_index()

# %%
pd.set_option('display.max_columns', 250)
pd.set_option('display.max_rows', 250)

# %%
df15
# Out:
#      Unnamed: 0       Revenue  Revenue Growth  Cost of Revenue  Gross Profit  \
# 0            PG  7.074900e+10         -0.0491     3.705600e+10  3.369300e+10
# 1          VIPS  6.193685e+09          0.6587     4.669038e+09  1.524648e+09
# 2            KR  1.084650e+11          0.1026     8.551200e+10  2.295300e+10
# 3           RAD  2.652838e+10          0.0393     1.895164e+10  7.576732e+09
# 4           GIS  1.763030e+10         -0.0156     1.168110e+10  5.949200e+09
# ...         ...           ...             ...              ...           ...
# 4115       TSRI  5.740290e+07          0.1590     4.808743e+07  9.315468e+06
# 4116       TZOO  1.239610e+08         -0.1911     1.814800e+07  1.058130e+08
# 4117      USATP  5.800000e+07             NaN     4.100000e+07  1.700000e+07
# 4118       WSTG  3.820900e+08          0.1213     3.555170e+08  2.657300e+07
# 4119        WTT  3.310911e+07         -0.1792     1.828123e+07  1.482787e+07
#
# ...

# %%
x = df_14['Unnamed: 0'].values
y = []
z = []
for i in x:
    if i in df_15['Unnamed: 0'].values:
        y.append(i)
    else:
        z.append(i)

# %%
len(y),len(z)
# Out:
# (3777, 31)

# %%
x = df_15['Unnamed: 0'].values
y = []
z1 = []
df115 = pd.DataFrame()
for i in x:
    if i in df_14['Unnamed: 0'].values:
        y.append(i)
    else:
        z1.append(i)

# %%
len(y),len(z1)
# Out:
# (3777, 343)

# %%
df15= df_15.set_index('Unnamed: 0')

# %%
df14= df_14.set_index('Unnamed: 0')

# %%
df15.loc[y,'Revenue Growth'].isnull().sum()
# Out:
# 160

# %%
df114 = df14.loc[y]

# %%
df15['Revenue Growth'].isnull().sum()
# Out:
# 340

# %%
df15.loc[y,'Revenue Growth'] = np.where(df15.loc[y,'Revenue Growth'].isna() & df14.loc[y,'Revenue']!=0,(df15.loc[y,'Revenue'] -df14.loc[y,'Revenue'])/df14.loc[y,'Revenue'] ,df15.loc[y,'Revenue Growth'])

# %%
df15['Revenue Growth'].value_counts()
# Out:
#  0.0000    195
# -1.0000     16
#  0.0428      7
#  0.0078      6
# -0.0446      6
#           ...
#  0.0719      1
# -0.0135      1
#  0.1477      1
# -0.5128      1
# -0.3232      1
# Name: Revenue Growth, Length: 2919, dtype: int64

# %%
df16= df_16.set_index('Unnamed: 0')

# %%
x = df_15['Unnamed: 0'].values
y = []
z = []
for i in x:
    if i in df_16['Unnamed: 0'].values:
        y.append(i)
    else:
        z.append(i)

# %%
df15['Revenue Growth'].isnull().sum()
# Out:
# 241

# %%
df16.loc[y,'Revenue Growth'] = np.where(df16.loc[y,'Revenue Growth'].isna() & df15.loc[y,'Revenue']!=0 ,(df16.loc[y,'Revenue'] -df15.loc[y,'Revenue'])/df15.loc[y,'Revenue'] ,df16.loc[y,'Revenue Growth'])

# %%
df16['Revenue Growth'].isnull().sum()
# Out:
# 546

# %%
df17= df_17.set_index('Unnamed: 0')

# %%
x = df_16['Unnamed: 0'].values
y = []
z = []
for i in x:
    if i in df_17['Unnamed: 0'].values:
        y.append(i)
    else:
        z.append(i)

# %%
df17['Revenue Growth'].isnull().sum()
# Out:
# 724

# %%
df17.loc[y,'Revenue Growth'] = np.where(df17.loc[y,'Revenue Growth'].isna() & df16.loc[y,'Revenue']!=0,(df17.loc[y,'Revenue'] -df16.loc[y,'Revenue'])/df16.loc[y,'Revenue'] ,df17.loc[y,'Revenue Growth'])

# %%
df17['Revenue Growth'].isnull().sum()
# Out:
# 617

# %%
df18= df_18.set_index('Unnamed: 0')

# %%
x = df_17['Unnamed: 0'].values
y = []
z = []
for i in x:
    if i in df_18['Unnamed: 0'].values:
        y.append(i)
    else:
        z.append(i)

# %%
df18['Revenue Growth'].isnull().sum()
# Out:
# 139

# %%
df18.loc[y,'Revenue Growth'] = np.where(df18.loc[y,'Revenue Growth'].isna() & df17.loc[y,'Revenue']!=0,(df18.loc[y,'Revenue'] -df17.loc[y,'Revenue'])/df17.loc[y,'Revenue'] ,df18.loc[y,'Revenue Growth'])

# %%
df18['Revenue Growth'].isnull().sum()
# Out:
# 61

# %%
x = df_17['Unnamed: 0'].values
y = []
z = []
for i in x:
    if i in df_18['Unnamed: 0'].values:
        y.append(i)
    else:
        z.append(i)

# %%
x = df_15['Unnamed: 0'].values
y1 = []
z1 = []
df115 = pd.DataFrame()
for i in x:
    if i in df_14['Unnamed: 0'].values:
        y1.append(i)
    else:
        z1.append(i)

# %%
val = (df15.loc[y1,'Receivables']  + df14.loc[y1,'Receivables']) /2

# %%
val2 = df15.loc[y1,'Average Receivables']

# %%
df15.loc[y1,'Average Receivables'] = np.where(df15.loc[y1,'Average Receivables'].isna() & df14.loc[y1,'Receivables']!=0,val,val2)

# %%
df15['Average Receivables'].isnull().sum()/len(df15)*100
# Out:
# 6.868932038834952

# %%
x = df_16['Unnamed: 0'].values
y1 = []
z1 = []
df115 = pd.DataFrame()
for i in x:
    if i in df_15['Unnamed: 0'].values:
        y1.append(i)
    else:
        z1.append(i)

# %%
val = (df16.loc[y1,'Receivables']  + df15.loc[y1,'Receivables']) /2

# %%
val2 = df16.loc[y1,'Average Receivables']

# %%
df16.loc[y1,'Average Receivables'] = np.where(df16.loc[y1,'Average Receivables'].isna() & df15.loc[y1,'Receivables']!=0,val,val2)

# %%
x = df_17['Unnamed: 0'].values
y1 = []
z1 = []
df115 = pd.DataFrame()
for i in x:
    if i in df_16['Unnamed: 0'].values:
        y1.append(i)
    else:
        z1.append(i)

# %%
val = (df17.loc[y1,'Receivables']  + df16.loc[y1,'Receivables']) /2

# %%
val2 = df17.loc[y1,'Average Receivables']

# %%
df17.loc[y1,'Average Receivables'] = np.where(df17.loc[y1,'Average Receivables'].isna() & df16.loc[y1,'Receivables']!=0,val,val2)

# %%
x = df_18['Unnamed: 0'].values
y1 = []
z1 = []
df115 = pd.DataFrame()
for i in x:
    if i in df_17['Unnamed: 0'].values:
        y1.append(i)
    else:
        z1.append(i)

# %%
val = (df18.loc[y1,'Receivables']  + df17.loc[y1,'Receivables']) /2

# %%
val2 = df18.loc[y1,'Average Receivables']

# %%
df18.loc[y1,'Average Receivables'] = np.where(df18.loc[y1,'Average Receivables'].isna()& df17.loc[y1,'Receivables']!=0,val,val2)

# %%
x = df_14['Unnamed: 0'].values
y = []
z = []
for i in x:
    if i in df_15['Unnamed: 0'].values:
        y.append(i)
    else:
        z.append(i)

# %%
val2 = df15.loc[y,'Average Payables']

# %%
val = (df14.loc[y,'Payables']  + df15.loc[y,'Payables']) /2

# %%
df16.loc[y,'Average Payables'] = np.where(df16.loc[y,'Average Payables'].isna(),val,val2)

# %%
x = df_16['Unnamed: 0'].values
y1 = []
z1 = []
df115 = pd.DataFrame()
for i in x:
    if i in df_15['Unnamed: 0'].values:
        y1.append(i)
    else:
        z1.append(i)

# %%
val2 = df16.loc[y1,'Average Payables']

# %%
val = (df16.loc[y1,'Payables']  + df15.loc[y1,'Payables']) /2

# %%
df16.loc[y1,'Average Payables'] = np.where(df16.loc[y1,'Average Payables'].isna(),val,val2)

# %%
x = df_17['Unnamed: 0'].values
y1 = []
z1 = []
df115 = pd.DataFrame()
for i in x:
    if i in df_16['Unnamed: 0'].values:
        y1.append(i)
    else:
        z1.append(i)

# %%
val2 = df17.loc[y1,'Average Payables']

# %%
val = (df17.loc[y1,'Payables']  + df16.loc[y1,'Payables']) /2

# %%
df17.loc[y1,'Average Payables'] = np.where(df17.loc[y1,'Average Payables'].isna(),val,val2)

# %%
x = df_18['Unnamed: 0'].values
y1 = []
z1 = []
df115 = pd.DataFrame()
for i in x:
    if i in df_17['Unnamed: 0'].values:
        y1.append(i)
    else:
        z1.append(i)

# %%
val2 = df18.loc[y1,'Average Payables']

# %%
val = (df18.loc[y1,'Payables']  + df17.loc[y1,'Payables']) /2

# %%
df18.loc[y1,'Average Payables'] = np.where(df18.loc[y1,'Average Payables'].isna(),val,val2)

# %%
x = df_14['Unnamed: 0'].values
y1 = []
z1 = []
for i in x:
    if i in df_15['Unnamed: 0'].values:
        y1.append(i)
    else:
        z1.append(i)

# %%
val2 = df15.loc[y1,'Receivables growth']
val = (df15.loc[y1,'Receivables']  - df14.loc[y1,'Receivables']) /df14.loc[y1,'Receivables']
df15.loc[y1,'Receivables growth'] = np.where(df15.loc[y1,'Receivables growth'].isna() & df14.loc[y1,'Receivables']!=0,val,val2)

# %%
x = df_15['Unnamed: 0'].values
y = []
z1 = []
for i in x:
    if i in df_16['Unnamed: 0'].values:
        y.append(i)
    else:
        z1.append(i)

# %%
val2 = df16.loc[y,'Receivables growth']
val = (df16.loc[y,'Receivables']  - df15.loc[y,'Receivables']) /df15.loc[y,'Receivables'] 
df16.loc[y,'Receivables growth'] = np.where(df16.loc[y,'Receivables growth'].isna() & df15.loc[y,'Receivables']!=0,val,val2)

# %%
x = df_16['Unnamed: 0'].values
y1 = []
z1 = []
for i in x:
    if i in df_17['Unnamed: 0'].values:
        y1.append(i)
    else:
        z1.append(i)

# %%
val2 = df17.loc[y1,'Receivables growth']
val = (df17.loc[y1,'Receivables']  - df16.loc[y1,'Receivables']) /df16.loc[y1,'Receivables']
df17.loc[y1,'Receivables growth'] = np.where(df17.loc[y1,'Receivables growth'].isna()& df16.loc[y1,'Receivables']!=0,val,val2)

# %%
x = df_18['Unnamed: 0'].values
y1 = []
z1 = []
for i in x:
    if i in df_17['Unnamed: 0'].values:
        y1.append(i)
    else:
        z1.append(i)

# %%
val2 = df18.loc[y1,'Receivables growth']
val = (df18.loc[y1,'Receivables']  - df17.loc[y1,'Receivables']) /df17.loc[y1,'Receivables']
df18.loc[y1,'Receivables growth'] = np.where(df18.loc[y1,'Receivables growth'].isna() & df17.loc[y1,'Receivables']!=0,val,val2)

# %%
x = df_14['Unnamed: 0'].values
y1 = []
z1 = []
for i in x:
    if i in df_15['Unnamed: 0'].values:
        y1.append(i)
    else:
        z1.append(i)

# %%
val2 = df15.loc[y1,'Asset Growth']
val = (df15.loc[y1,'Total assets']  - df14.loc[y1,'Total assets']) /df14.loc[y1,'Total assets']
df15.loc[y1,'Asset Growth'] = np.where(df15.loc[y1,'Asset Growth'].isna() & df14.loc[y1,'Total assets']!=0,val,val2)

# %%
x = df_15['Unnamed: 0'].values
y1 = []
z1 = []
for i in x:
    if i in df_16['Unnamed: 0'].values:
        y1.append(i)
    else:
        z1.append(i)
val2 = df16.loc[y1,'Asset Growth']
val = (df16.loc[y1,'Total assets']  - df15.loc[y1,'Total assets']) /df15.loc[y1,'Total assets']
df16.loc[y1,'Asset Growth'] = np.where(df16.loc[y1,'Asset Growth'].isna()  & df15.loc[y1,'Total assets']!=0,val,val2)

# %%
x = df_17['Unnamed: 0'].values
y1 = []
z1 = []
for i in x:
    if i in df_18['Unnamed: 0'].values:
        y1.append(i)
    else:
        z1.append(i)

# %%
val2 = df18.loc[y1,'Asset Growth']
val = (df18.loc[y1,'Total assets']  - df17.loc[y1,'Total assets']) /df17.loc[y1,'Total assets']
df18.loc[y1,'Asset Growth'] = np.where(df18.loc[y1,'Asset Growth'].isna() & df17.loc[y1,'Total assets']!=0, val,val2)

# %%
x = df_17['Unnamed: 0'].values
y1 = []
z1 = []
for i in x:
    if i in df_16['Unnamed: 0'].values:
        y1.append(i)
    else:
        z1.append(i)

# %%
val2 = df17.loc[y1,'Asset Growth']
val = (df17.loc[y1,'Total assets']  - df16.loc[y1,'Total assets']) /df16.loc[y1,'Total assets']
df17.loc[y1,'Asset Growth'] = np.where(df17.loc[y1,'Asset Growth'].isna() & df16.loc[y1,'Total assets']!=0,val,val2)

# %%
x = df_14['Unnamed: 0'].values
y1 = []
z1 = []
for i in x:
    if i in df_15['Unnamed: 0'].values:
        y1.append(i)
    else:
        z1.append(i)
val2 = df15.loc[y1,'Book Value per Share Growth']
val = (df15.loc[y1,'Book Value per Share']  - df14.loc[y1,'Book Value per Share']) /df14.loc[y1,'Book Value per Share']
df15.loc[y1,'Book Value per Share Growth'] = np.where(df15.loc[y1,'Book Value per Share Growth'].isna() & df14.loc[y1,'Book Value per Share']!=0,val,val2)

# %%
x = df_16['Unnamed: 0'].values
y1 = []
z1 = []
for i in x:
    if i in df_15['Unnamed: 0'].values:
        y1.append(i)
    else:
        z1.append(i)
val2 = df16.loc[y1,'Book Value per Share Growth']
val = (df16.loc[y1,'Book Value per Share']  - df15.loc[y1,'Book Value per Share']) /df15.loc[y1,'Book Value per Share']
df16.loc[y1,'Book Value per Share Growth'] = np.where(df16.loc[y1,'Book Value per Share Growth'].isna() & df15.loc[y1,'Book Value per Share']!=0,val,val2)

# %%
x = df_17['Unnamed: 0'].values
y1 = []
z1 = []
for i in x:
    if i in df_16['Unnamed: 0'].values:
        y1.append(i)
    else:
        z1.append(i)

# %%
val2 = df17.loc[y1,'Book Value per Share Growth']

# %%
val = (df17.loc[y1,'Book Value per Share']  - df16.loc[y1,'Book Value per Share']) /df16.loc[y1,'Book Value per Share']

# %%
df17.loc[y1,'Book Value per Share Growth'] = np.where(df17.loc[y1,'Book Value per Share Growth'].isna() & df16.loc[y1,'Book Value per Share']!=0,val,val2)

# %%
x = df_17['Unnamed: 0'].values
y1 = []
z1 = []
for i in x:
    if i in df_18['Unnamed: 0'].values:
        y1.append(i)
    else:
        z1.append(i)
val2 = df18.loc[y1,'Book Value per Share Growth']
val = (df18.loc[y1,'Book Value per Share']  - df17.loc[y1,'Book Value per Share']) /df17.loc[y1,'Book Value per Share']
df18.loc[y1,'Book Value per Share Growth'] = np.where(df18.loc[y1,'Book Value per Share Growth'].isna() & df17.loc[y1,'Book Value per Share']!=0,val,val2)

# %%
x = df_14['Unnamed: 0'].values
y1 = []
z1 = []
for i in x:
    if i in df_15['Unnamed: 0'].values:
        y1.append(i)
    else:
        z1.append(i)
val2 = df15.loc[y1,'Debt Growth']
val = (df15.loc[y1,'Total debt']  - df14.loc[y1,'Total debt']) /df14.loc[y1,'Total debt']
df15.loc[y1,'Debt Growth'] = np.where(df15.loc[y1,'Debt Growth'].isna() & df14.loc[y1,'Total debt']!=0,val,val2)

# %%
x = df_16['Unnamed: 0'].values
y1 = []
z1 = []
for i in x:
    if i in df_15['Unnamed: 0'].values:
        y1.append(i)
    else:
        z1.append(i)
val2 = df16.loc[y1,'Debt Growth']
val = (df16.loc[y1,'Total debt']  - df15.loc[y1,'Total debt']) /df15.loc[y1,'Total debt']
df16.loc[y1,'Debt Growth'] = np.where(df16.loc[y1,'Debt Growth'].isna() & df15.loc[y1,'Total debt']!=0,val,val2)

# %%
x = df_16['Unnamed: 0'].values
y1 = []
z1 = []
for i in x:
    if i in df_17['Unnamed: 0'].values:
        y1.append(i)
    else:
        z1.append(i)
val2 = df17.loc[y1,'Debt Growth']
val = (df17.loc[y1,'Total debt']  - df16.loc[y1,'Total debt']) /df16.loc[y1,'Total debt']
df17.loc[y1,'Debt Growth'] = np.where(df17.loc[y1,'Debt Growth'].isna() & df16.loc[y1,'Total debt']!=0,val,val2)

# %%
x = df_18['Unnamed: 0'].values
y1 = []
z1 = []
for i in x:
    if i in df_17['Unnamed: 0'].values:
        y1.append(i)
    else:
        z1.append(i)
val2 = df18.loc[y1,'Debt Growth']
val = (df18.loc[y1,'Total debt']  - df17.loc[y1,'Total debt']) /df17.loc[y1,'Total debt']
df18.loc[y1,'Debt Growth'] = np.where(df18.loc[y1,'Debt Growth'].isna() & df17.loc[y1,'Total debt']!=0,val,val2)

# %%
x = df_14['Unnamed: 0'].values
y1 = []
z1 = []
for i in x:
    if i in df_15['Unnamed: 0'].values:
        y1.append(i)
    else:
        z1.append(i)
val2 = df15.loc[y1,'R&D Expense Growth']
val = (df15.loc[y1,'R&D Expenses']  - df14.loc[y1,'R&D Expenses']) /df14.loc[y1,'R&D Expenses']
df15.loc[y1,'R&D Expense Growth'] = np.where(df15.loc[y1,'R&D Expense Growth'].isna() & df14.loc[y1,'R&D Expenses']!=0,val,val2)

# %%
x = df_15['Unnamed: 0'].values
y1 = []
z1 = []
for i in x:
    if i in df_16['Unnamed: 0'].values:
        y1.append(i)
    else:
        z1.append(i)
val2 = df16.loc[y1,'R&D Expense Growth']
val = (df16.loc[y1,'R&D Expenses']  - df15.loc[y1,'R&D Expenses']) /df15.loc[y1,'R&D Expenses']
df16.loc[y1,'R&D Expense Growth'] = np.where(df15.loc[y1,'R&D Expense Growth'].isna()& df15.loc[y1,'R&D Expenses']!=0,val,val2)

# %%
x = df_17['Unnamed: 0'].values
y1 = []
z1 = []
for i in x:
    if i in df_16['Unnamed: 0'].values:
        y1.append(i)
    else:
        z1.append(i)
val2 = df17.loc[y1,'R&D Expense Growth']
val = (df17.loc[y1,'R&D Expenses']  - df16.loc[y1,'R&D Expenses']) /df16.loc[y1,'R&D Expenses']
df17.loc[y1,'R&D Expense Growth'] = np.where(df17.loc[y1,'R&D Expense Growth'].isna() & df16.loc[y1,'R&D Expenses']!=0,val,val2)

# %%
x = df_17['Unnamed: 0'].values
y1 = []
z1 = []
for i in x:
    if i in df_18['Unnamed: 0'].values:
        y1.append(i)
    else:
        z1.append(i)
val2 = df18.loc[y1,'R&D Expense Growth']
val = (df18.loc[y1,'R&D Expenses']  - df17.loc[y1,'R&D Expenses']) /df17.loc[y1,'R&D Expenses']
df18.loc[y1,'R&D Expense Growth'] = np.where(df18.loc[y1,'R&D Expense Growth'].isna() & df17.loc[y1,'R&D Expenses']!=0,val,val2)

# %%
x = df_14['Unnamed: 0'].values
y1 = []
z1 = []
for i in x:
    if i in df_15['Unnamed: 0'].values:
        y1.append(i)
    else:
        z1.append(i)
val2 = df15.loc[y1,'R&D Expense Growth']
val = (df15.loc[y1,'SG&A Expense']  - df14.loc[y1,'SG&A Expense']) /df14.loc[y1,'SG&A Expense']
df15.loc[y1,'SG&A Expenses Growth'] = np.where(df15.loc[y1,'SG&A Expenses Growth'].isna() & df14.loc[y1,'SG&A Expense']!=0,val,val2)

# %%
x = df_16['Unnamed: 0'].values
y1 = []
z1 = []
for i in x:
    if i in df_15['Unnamed: 0'].values:
        y1.append(i)
    else:
        z1.append(i)
val2 = df16.loc[y1,'R&D Expense Growth']
val = (df15.loc[y1,'SG&A Expense']  - df15.loc[y1,'SG&A Expense']) /df15.loc[y1,'SG&A Expense']
df16.loc[y1,'SG&A Expenses Growth'] = np.where(df16.loc[y1,'SG&A Expenses Growth'].isna() & df15.loc[y1,'SG&A Expense']!=0,val,val2)

# %%
x = df_16['Unnamed: 0'].values
y1 = []
z1 = []
for i in x:
    if i in df_17['Unnamed: 0'].values:
        y1.append(i)
    else:
        z1.append(i)
val2 = df17.loc[y1,'R&D Expense Growth']
val = (df17.loc[y1,'SG&A Expense']  - df16.loc[y1,'SG&A Expense']) /df16.loc[y1,'SG&A Expense']
df17.loc[y1,'SG&A Expenses Growth'] = np.where(df17.loc[y1,'SG&A Expenses Growth'].isna() & df16.loc[y1,'SG&A Expense']!=0,val,val2)

# %%
x = df_18['Unnamed: 0'].values
y1 = []
z1 = []
for i in x:
    if i in df_17['Unnamed: 0'].values:
        y1.append(i)
    else:
        z1.append(i)
val2 = df18.loc[y1,'R&D Expense Growth']
val = (df18.loc[y1,'SG&A Expense']  - df17.loc[y1,'SG&A Expense']) /df17.loc[y1,'SG&A Expense']
df18.loc[y1,'SG&A Expenses Growth'] = np.where(df18.loc[y1,'SG&A Expenses Growth'].isna() & df17.loc[y1,'SG&A Expense']!=0,val,val2)

# %%
x = df_15['Unnamed: 0'].values
y1 = []
z1 = []
df115 = pd.DataFrame()
for i in x:
    if i in df_14['Unnamed: 0'].values:
        y1.append(i)
    else:
        z1.append(i)
df15.loc[y1,'Net Income Growth'] = np.where(df15.loc[y1,'Net Income Growth'].isna() & df14.loc[y1,'Net Income']!=0,(df15.loc[y1,'Net Income'] -df14.loc[y1,'Net Income'])/df14.loc[y1,'Net Income'] ,df15.loc[y1,'Net Income Growth'])

# %%
x = df_15['Unnamed: 0'].values
y = []
z = []
for i in x:
    if i in df_16['Unnamed: 0'].values:
        y.append(i)
    else:
        z.append(i)
df16.loc[y,'Net Income Growth'] = np.where(df16.loc[y,'Net Income Growth'].isna() & df15.loc[y,'Net Income']!=0,(df16.loc[y,'Net Income'] -df15.loc[y,'Net Income'])/df15.loc[y,'Net Income'] ,df16.loc[y,'Net Income Growth'])

# %%
x = df_16['Unnamed: 0'].values
y = []
z = []
for i in x:
    if i in df_17['Unnamed: 0'].values:
        y.append(i)
    else:
        z.append(i)
df17.loc[y,'Net Income Growth'] = np.where(df17.loc[y,'Net Income Growth'].isna() & df16.loc[y,'Net Income']!=0,(df17.loc[y,'Net Income'] -df16.loc[y,'Net Income'])/df16.loc[y,'Net Income'] ,df17.loc[y,'Net Income Growth'])

# %%
x = df_17['Unnamed: 0'].values
y = []
z = []
for i in x:
    if i in df_18['Unnamed: 0'].values:
        y.append(i)
    else:
        z.append(i)
df18.loc[y,'Net Income Growth'] = np.where(df18.loc[y,'Net Income Growth'].isna() & df17.loc[y,'Net Income']!=0,(df18.loc[y,'Net Income'] -df17.loc[y,'Net Income'])/df17.loc[y,'Net Income'] ,df18.loc[y,'Net Income Growth'])

# %%
x = df_15['Unnamed: 0'].values
y1 = []
z1 = []
df115 = pd.DataFrame()
for i in x:
    if i in df_14['Unnamed: 0'].values:
        y1.append(i)
    else:
        z1.append(i)
df15.loc[y1,'EPS Growth'] = np.where(df15.loc[y1,'EPS Growth'].isna() & df14.loc[y1,'EPS']!=0,(df15.loc[y1,'EPS'] -df14.loc[y1,'EPS'])/df14.loc[y1,'EPS'] ,df15.loc[y1,'EPS Growth'])

# %%
x = df_15['Unnamed: 0'].values
y = []
z = []
for i in x:
    if i in df_16['Unnamed: 0'].values:
        y.append(i)
    else:
        z.append(i)
df16.loc[y,'EPS Growth'] = np.where(df16.loc[y,'EPS Growth'].isna() & df15.loc[y,'EPS']!=0,(df16.loc[y,'EPS'] -df15.loc[y,'EPS'])/df15.loc[y,'EPS'] ,df16.loc[y,'EPS Growth'])

# %%
x = df_16['Unnamed: 0'].values
y = []
z = []
for i in x:
    if i in df_17['Unnamed: 0'].values:
        y.append(i)
    else:
        z.append(i)
df17.loc[y,'EPS Growth'] = np.where(df17.loc[y,'EPS Growth'].isna() & df16.loc[y,'EPS']!=0,(df17.loc[y,'EPS'] -df16.loc[y,'EPS'])/df16.loc[y,'EPS'] ,df17.loc[y,'EPS Growth'])

# %%
x = df_17['Unnamed: 0'].values
y = []
z = []
for i in x:
    if i in df_18['Unnamed: 0'].values:
        y.append(i)
    else:
        z.append(i)
df18.loc[y,'EPS Growth'] = np.where(df18.loc[y,'EPS Growth'].isna() & df17.loc[y,'EPS']!=0,(df18.loc[y,'EPS'] -df17.loc[y,'EPS'])/df17.loc[y,'EPS'] ,df18.loc[y,'EPS Growth'])

# %%
x = df_15['Unnamed: 0'].values
y1 = []
z1 = []
df115 = pd.DataFrame()
for i in x:
    if i in df_14['Unnamed: 0'].values:
        y1.append(i)
    else:
        z1.append(i)
df15.loc[y1,'EPS Diluted Growth'] = np.where(df15.loc[y1,'EPS Diluted Growth'].isna() & df14.loc[y1,'EPS Diluted']!=0,(df15.loc[y1,'EPS Diluted'] -df14.loc[y1,'EPS Diluted'])/df14.loc[y1,'EPS Diluted'] ,df15.loc[y1,'EPS Diluted Growth'])

# %%
x = df_15['Unnamed: 0'].values
y = []
z = []
for i in x:
    if i in df_16['Unnamed: 0'].values:
        y.append(i)
    else:
        z.append(i)
df16.loc[y,'EPS Diluted Growth'] = np.where(df16.loc[y,'EPS Diluted Growth'].isna() & df15.loc[y,'EPS Diluted']!=0,(df16.loc[y,'EPS Diluted'] -df15.loc[y,'EPS Diluted'])/df15.loc[y,'EPS Diluted'] ,df16.loc[y,'EPS Diluted Growth'])

# %%
x = df_16['Unnamed: 0'].values
y = []
z = []
for i in x:
    if i in df_17['Unnamed: 0'].values:
        y.append(i)
    else:
        z.append(i)
df17.loc[y,'EPS Diluted Growth'] = np.where(df17.loc[y,'EPS Diluted Growth'].isna() & df16.loc[y,'EPS Diluted']!=0,(df17.loc[y,'EPS Diluted'] -df16.loc[y,'EPS Diluted'])/df16.loc[y,'EPS Diluted'] ,df17.loc[y,'EPS Diluted Growth'])

# %%
x = df_17['Unnamed: 0'].values
y = []
z = []
for i in x:
    if i in df_18['Unnamed: 0'].values:
        y.append(i)
    else:
        z.append(i)
df18.loc[y,'EPS Diluted Growth'] = np.where(df18.loc[y,'EPS Diluted Growth'].isna() & df17.loc[y,'EPS Diluted']!=0,(df18.loc[y,'EPS Diluted'] -df17.loc[y,'EPS Diluted'])/df17.loc[y,'EPS Diluted'] ,df18.loc[y,'EPS Diluted Growth'])

# %%
x = df_15['Unnamed: 0'].values
y = []
z1 = []
df115 = pd.DataFrame()
for i in x:
    if i in df_14['Unnamed: 0'].values:
        y.append(i)
    else:
        z1.append(i)
df15.loc[y,'Weighted Average Shares Growth'] = np.where(df15.loc[y,'Weighted Average Shares Growth'].isna() & df14.loc[y,'Weighted Average Shs Out'] !=0 ,(df15.loc[y,'Weighted Average Shs Out'] -df14.loc[y,'Weighted Average Shs Out'])/df14.loc[y,'Weighted Average Shs Out'] ,df15.loc[y,'Weighted Average Shares Growth'])

# %%
x = df_15['Unnamed: 0'].values
y = []
z = []
for i in x:
    if i in df_16['Unnamed: 0'].values:
        y.append(i)
    else:
        z.append(i)
df16.loc[y,'Weighted Average Shares Growth'] = np.where(df16.loc[y,'Weighted Average Shares Growth'].isna()  & df15.loc[y,'Weighted Average Shs Out'] !=0,(df16.loc[y,'Weighted Average Shs Out'] -df15.loc[y,'Weighted Average Shs Out'])/df15.loc[y,'Weighted Average Shs Out'] ,df16.loc[y,'Weighted Average Shares Growth'])

# %%
x = df_16['Unnamed: 0'].values
y = []
z = []
for i in x:
    if i in df_17['Unnamed: 0'].values:
        y.append(i)
    else:
        z.append(i)
df17.loc[y,'Weighted Average Shares Growth'] = np.where(df17.loc[y,'Weighted Average Shares Growth'].isna()  & df16.loc[y,'Weighted Average Shs Out'] !=0,(df17.loc[y,'Weighted Average Shs Out'] -df16.loc[y,'Weighted Average Shs Out'])/df16.loc[y,'Weighted Average Shs Out'] ,df17.loc[y,'Weighted Average Shares Growth'])

# %%
x = df_17['Unnamed: 0'].values
y = []
z = []
for i in x:
    if i in df_18['Unnamed: 0'].values:
        y.append(i)
    else:
        z.append(i)
df18.loc[y,'Weighted Average Shares Growth'] = np.where(df18.loc[y,'Weighted Average Shares Growth'].isna()  & df17.loc[y,'Weighted Average Shs Out'] !=0,(df18.loc[y,'Weighted Average Shs Out'] -df17.loc[y,'Weighted Average Shs Out'])/df17.loc[y,'Weighted Average Shs Out'] ,df18.loc[y,'Weighted Average Shares Growth'])

# %%
x = df_15['Unnamed: 0'].values
y = []
z1 = []
df115 = pd.DataFrame()
for i in x:
    if i in df_14['Unnamed: 0'].values:
        y.append(i)
    else:
        z1.append(i)
df15.loc[y,'Dividends per Share Growth'] = np.where(df15.loc[y,'Dividends per Share Growth'].isna() & df14.loc[y,'Dividend per Share'] != 0,(df15.loc[y,'Dividend per Share'] -df14.loc[y,'Dividend per Share'])/df14.loc[y,'Dividend per Share'] ,df15.loc[y,'Dividends per Share Growth'])

# %%
x = df_15['Unnamed: 0'].values
y = []
z1 = []
df115 = pd.DataFrame()
for i in x:
    if i in df_16['Unnamed: 0'].values:
        y.append(i)
    else:
        z1.append(i)
df16.loc[y,'Dividends per Share Growth'] = np.where(df16.loc[y,'Dividends per Share Growth'].isna() & df15.loc[y,'Dividend per Share'] != 0,(df16.loc[y,'Dividend per Share'] -df15.loc[y,'Dividend per Share'])/df15.loc[y,'Dividend per Share'] ,df16.loc[y,'Dividends per Share Growth'])

# %%
x = df_17['Unnamed: 0'].values
y = []
z1 = []
for i in x:
    if i in df_16['Unnamed: 0'].values:
        y.append(i)
    else:
        z1.append(i)
df17.loc[y,'Dividends per Share Growth'] = np.where(df17.loc[y,'Dividends per Share Growth'].isna() & df16.loc[y,'Dividend per Share'] != 0,(df17.loc[y,'Dividend per Share'] -df16.loc[y,'Dividend per Share'])/df16.loc[y,'Dividend per Share'] ,df17.loc[y,'Dividends per Share Growth'])

# %%
x = df_17['Unnamed: 0'].values
y = []
z1 = []
for i in x:
    if i in df_18['Unnamed: 0'].values:
        y.append(i)
    else:
        z1.append(i)
df18.loc[y,'Dividends per Share Growth'] = np.where(df18.loc[y,'Dividends per Share Growth'].isna() & df17.loc[y,'Dividend per Share'] != 0,(df18.loc[y,'Dividend per Share'] -df17.loc[y,'Dividend per Share'])/df17.loc[y,'Dividend per Share'] ,df18.loc[y,'Dividends per Share Growth'])

# %%
x = df_15['Unnamed: 0'].values
y = []
z1 = []
for i in x:
    if i in df_14['Unnamed: 0'].values:
        y.append(i)
df15.loc[y,'Operating Cash Flow growth'] = np.where(df15.loc[y,'Operating Cash Flow growth'].isna() & df14.loc[y,'Operating Cash Flow'] != 0,(df15.loc[y,'Operating Cash Flow'] -df14.loc[y,'Operating Cash Flow'])/df14.loc[y,'Operating Cash Flow'] ,df15.loc[y,'Operating Cash Flow growth'])

# %%
x = df_15['Unnamed: 0'].values
y = []
z1 = []
for i in x:
    if i in df_16['Unnamed: 0'].values:
        y.append(i)
df16.loc[y,'Operating Cash Flow growth'] = np.where(df16.loc[y,'Operating Cash Flow growth'].isna() & df15.loc[y,'Operating Cash Flow'] != 0,(df16.loc[y,'Operating Cash Flow'] -df15.loc[y,'Operating Cash Flow'])/df15.loc[y,'Operating Cash Flow'] ,df16.loc[y,'Operating Cash Flow growth'])

# %%
x = df_17['Unnamed: 0'].values
y = []
z1 = []
for i in x:
    if i in df_16['Unnamed: 0'].values:
        y.append(i)
df17.loc[y,'Operating Cash Flow growth'] = np.where(df17.loc[y,'Operating Cash Flow growth'].isna() & df16.loc[y,'Operating Cash Flow'] != 0,(df17.loc[y,'Operating Cash Flow'] -df16.loc[y,'Operating Cash Flow'])/df16.loc[y,'Operating Cash Flow'] ,df17.loc[y,'Operating Cash Flow growth'])

# %%
x = df_17['Unnamed: 0'].values
y = []
z1 = []
for i in x:
    if i in df_18['Unnamed: 0'].values:
        y.append(i)
df18.loc[y,'Operating Cash Flow growth'] = np.where(df18.loc[y,'Operating Cash Flow growth'].isna() & df17.loc[y,'Operating Cash Flow'] != 0,(df18.loc[y,'Operating Cash Flow'] -df17.loc[y,'Operating Cash Flow'])/df17.loc[y,'Operating Cash Flow'] ,df18.loc[y,'Operating Cash Flow growth'])

# %%
x = df_15['Unnamed: 0'].values
y = []
z1 = []
for i in x:
    if i in df_14['Unnamed: 0'].values:
        y.append(i)
df15.loc[y,'Free Cash Flow growth'] = np.where(df15.loc[y,'Free Cash Flow growth'].isna() & df14.loc[y,'Free Cash Flow'] != 0,(df15.loc[y,'Free Cash Flow'] -df14.loc[y,'Free Cash Flow'])/df14.loc[y,'Free Cash Flow'] ,df15.loc[y,'Free Cash Flow growth'])

# %%
x = df_15['Unnamed: 0'].values
y = []
z1 = []
for i in x:
    if i in df_16['Unnamed: 0'].values:
        y.append(i)
df16.loc[y,'Free Cash Flow growth'] = np.where(df16.loc[y,'Free Cash Flow growth'].isna() & df15.loc[y,'Free Cash Flow'] != 0,(df16.loc[y,'Free Cash Flow'] -df15.loc[y,'Free Cash Flow'])/df15.loc[y,'Free Cash Flow'] ,df16.loc[y,'Free Cash Flow growth'])

# %%
x = df_17['Unnamed: 0'].values
y = []
z1 = []
for i in x:
    if i in df_16['Unnamed: 0'].values:
        y.append(i)
df17.loc[y,'Free Cash Flow growth'] = np.where(df17.loc[y,'Free Cash Flow growth'].isna() & df16.loc[y,'Free Cash Flow'] != 0,(df17.loc[y,'Free Cash Flow'] -df16.loc[y,'Free Cash Flow'])/df16.loc[y,'Free Cash Flow'] ,df16.loc[y,'Free Cash Flow growth'])

# %%
x = df_18['Unnamed: 0'].values
y = []
z1 = []
for i in x:
    if i in df_17['Unnamed: 0'].values:
        y.append(i)
df18.loc[y,'Free Cash Flow growth'] = np.where(df18.loc[y,'Free Cash Flow growth'].isna() & df17.loc[y,'Free Cash Flow'] != 0,(df18.loc[y,'Free Cash Flow'] -df17.loc[y,'Free Cash Flow'])/df17.loc[y,'Free Cash Flow'] ,df18.loc[y,'Free Cash Flow growth'])

# %%
df15['Free Cash Flow growth']
# Out:
# Unnamed: 0
# PG       0.0754
# VIPS    -2.3235
# KR       0.1134
# RAD     -0.3967
# GIS     -0.0227
#           ...
# TSRI     0.4019
# TZOO     1.5389
# USATP   -0.2500
# WSTG     0.4695
# WTT     -0.8493
# Name: Free Cash Flow growth, Length: 4120, dtype: float64

# %%
df = pd.concat([df14,df15,df16,df17,df18])

# %%
df = df.drop('10Y Revenue Growth (per Share)',1)

# %%
df = df.drop('10Y Operating CF Growth (per Share)',1)

# %%
df = df.drop('10Y Net Income Growth (per Share)',1)

# %%
df = df.drop('10Y Shareholders Equity Growth (per Share)',1)
df = df.drop('10Y Dividend per Share Growth (per Share)',1)

# %%
df.isnull().sum()/len(df)*100
# Out:
# Revenue                                       5.304163
# Revenue Growth                                7.704851
# Cost of Revenue                               8.021923
# Gross Profit                                  5.467228
# R&D Expenses                                  9.684287
# SG&A Expense                                  7.559904
# Operating Expenses                            7.709381
# Operating Income                              4.987091
# Interest Expense                              7.786384
# Earnings before Tax                           6.178376
# Income Tax Expense                            7.193006
# Net Income - Non-Controlling int             10.232369
# Net Income - Discontinued ops                10.232369
# Net Income                                    7.088825
# Preferred Dividends                          10.232369
# Net Income Com                                6.300675
# EPS                                           5.893011
# ...

# %%
pd.set_option('display.max_columns', 250)
pd.set_option('display.max_rows', 250)

# %%
7.440100e+10 +7.090000e+08 + 2.851000e+09 +3.141000e+09
# Out:
# 81102000000.0

# %%
df['Total shareholders equity'].value_counts()
# Out:
# 0.000000e+00    57
# 5.000000e+06    18
# 1.000000e+06    14
# 5.000001e+06     9
# 1.000000e+07     7
#                 ..
# 3.230209e+09     1
# 9.790200e+07     1
# 5.381200e+07     1
# 1.327900e+08     1
# 9.436100e+07     1
# Name: Total shareholders equity, Length: 20069, dtype: int64

# %%
df['ROE'] = np.where(df['ROE'].isna() & df['Total shareholders equity'] !=0, (df['Net Income']/df['Total shareholders equity']),df['Net Income'] )

# %%
df['daysOfSalesOutstanding']= np.where(df['daysOfSalesOutstanding'].isna() & df['Revenue'] != 0,((df['Average Receivables']/df['Revenue']) *344),df['daysOfSalesOutstanding'] )

# %%
df['Days of Inventory on Hand'] = np.where(df['Days of Inventory on Hand'].isna() & df['Cost of Revenue']!=0,((df['Average Inventory']*344)/df['Cost of Revenue']),df['Days of Inventory on Hand'] )

# %%
df['Receivables Turnover'] = np.where(df['Receivables Turnover'].isna() & df['Average Receivables']!=0, (df['Revenue']/df['Average Receivables']),df['Receivables Turnover'] )

# %%
df['Payables Turnover'] = np.where(df['Payables Turnover'].isna() & df['Average Payables']!=0, (df['Net Income']/df['Average Payables']),df['Payables Turnover'] )

# %%
df['Inventory Turnover']= np.where(df['Inventory Turnover'].isna() & df['Average Inventory']!=0,(df['Revenue']/df['Average Inventory']),df['Inventory Turnover'])

# %%
df['Revenue Growth'].isna().sum()/len(df)
# Out:
# 0.0770485120260905

# %%
df['Earnings before Tax'] = np.where((df['Earnings before Tax'].isna()) ,(df['Revenue'] -df['R&D Expenses']-df['SG&A Expense']-df['Operating Expenses']) ,df['Earnings before Tax'])

# %%
df['Earnings before Tax'].notnull().sum()/len(df)
# Out:
# 0.9382162431489786

# %%
df['Earnings before Tax'].notnull().sum()/len(df)
# Out:
# 0.9382162431489786

# %%
df['EPS'] = np.where((df['EPS'].isna()) & df['Weighted Average Shs Out']!=0 ,(df['Net Income'] / df['Weighted Average Shs Out']) ,df['EPS'])

# %%
df['EPS'].isnull().sum()/len(df)*100
# Out:
# 5.856774018208996

# %%
df['EPS Diluted'].isnull().sum()/len(df)*100
# Out:
# 5.852244417266839

# %%
df['EBITDA Margin'] = np.where((df['EBITDA Margin'].isna()) & df['Revenue'] !=0,(df['EBITDA']/df['Revenue'])*100 ,df['EBITDA Margin'])

# %%
df['EBITDA Margin'].isnull().sum()/len(df)*100
# Out:
# 10.984282284730714

# %%
df['EBIT Margin'] = np.where((df['EBIT Margin'].isna()) &df['Revenue']!=0,(df['EBIT']/df['Revenue'])*100 ,df['EBIT Margin'])

# %%
df['EBIT Margin'].isnull().sum()/len(df)*100
# Out:
# 7.546315169633555

# %%
df['Earnings Before Tax Margin'] = np.where((df['Earnings Before Tax Margin'].isna()) & df['Revenue']!=0 ,(df['Earnings before Tax']/df['Revenue'])*100 ,df['Earnings Before Tax Margin'])

# %%
df['Earnings Before Tax Margin'].isnull().sum()/len(df)*100
# Out:
# 5.385695520224668

# %%
df['Net Profit Margin'] = np.where((df['Net Profit Margin'].isna()) & df['Revenue']!=0 ,(df['Net Income']/df['Revenue']) ,df['Net Profit Margin'])

# %%
df['Net Profit Margin'].isnull().sum()/len(df)*100
# Out:
# 7.7682656157992485

# %%
df['Total assets'] = np.where((df['Total assets'].isna()) ,(df['Total current assets'] - df['Total current assets']) ,df['Total assets'])

# %%
df['Total assets'].isnull().sum()/len(df)*100
# Out:
# 5.91112922951488

# %%
df['Total debt'] = np.where((df['Total debt'].isna()) ,(df['Long-term debt'] - df['Short-term debt']) ,df['Total debt'])

# %%
df['Total debt'].isnull().sum()/len(df)*100
# Out:
# 7.32889432441002

# %%
df['Total liabilities'] = np.where((df['Total liabilities'].isna()) ,(df['Total current liabilities'] + df['Total non-current liabilities']) ,df['Total liabilities'])

# %%
df['Total liabilities'].isnull().sum()/len(df)*100
# Out:
# 6.323322915251166

# %%
df['Net cash flow / Change in cash'] = np.where((df['Net cash flow / Change in cash'].isna()) ,(df['Investing Cash flow'] + df['Operating Cash Flow']+df['Financing Cash Flow']) ,df['Net cash flow / Change in cash'])

# %%
df['Net cash flow / Change in cash'].isnull().sum()/len(df)*100
# Out:
# 4.425420120487385

# %%
df['priceToSalesRatio'] = np.where((df['priceToSalesRatio'].isna()) & df['Revenue']!=0 ,(df['Market Cap']/df['Revenue']) ,df['priceToSalesRatio'])

# %%
df['priceToSalesRatio'].isnull().sum()/len(df)*100
# Out:
# 10.128187706663043

# %%
df['priceToFreeCashFlowsRatio'] = np.where((df['priceToFreeCashFlowsRatio'].isna()) & df['Free Cash Flow']!=0 ,(df['Market Cap']/df['Free Cash Flow']) ,df['priceToFreeCashFlowsRatio'])

# %%
df['priceToFreeCashFlowsRatio'].isnull().sum()/len(df)*100
# Out:
# 10.218779725506183

# %%
df['priceToOperatingCashFlowsRatio'] = np.where((df['priceToOperatingCashFlowsRatio'].isna()) & df['Operating Cash Flow']!=0 ,(df['Market Cap']/df['Operating Cash Flow']) ,df['priceToOperatingCashFlowsRatio'])

# %%
df['priceToOperatingCashFlowsRatio'].isnull().sum()/len(df)*100
# Out:
# 13.914934094306291

# %%
df['priceEarningsToGrowthRatio'] = np.where((df['priceEarningsToGrowthRatio'].isna()) & df['EPS Growth']!=0,(df['priceEarningsRatio']/df['EPS Growth']) ,df['priceEarningsToGrowthRatio'])

# %%
df['priceEarningsToGrowthRatio'].isnull().sum()/len(df)*100
# Out:
# 11.55048240250034

# %%
df['ebitperRevenue'] = np.where((df['ebitperRevenue'].isna()) & df['Revenue']!=0 ,(df['EBIT']/df['Revenue']) ,df['ebitperRevenue'])

# %%
df['ebitperRevenue'].isnull().sum()/len(df)*100
# Out:
# 10.137246908547356

# %%
df['ebtperEBIT'] = np.where((df['ebtperEBIT'].isna()) &df['EBIT']!=0, (df['Earnings before Tax']/df['EBIT']) ,df['ebtperEBIT'])

# %%
df['ebtperEBIT'].isnull().sum()/len(df)*100
# Out:
# 8.311817728858088

# %%
df['niperEBT'] = np.where((df['niperEBT'].isna()) & df['Earnings before Tax']!=0 ,(df['Net Income']/df['Earnings before Tax']) ,df['niperEBT'])

# %%
df['niperEBT'].isnull().sum()/len(df)*100
# Out:
# 7.433075146079631

# %%
df = df.drop('nIperEBT',1)

# %%
df['grossProfitMargin'] = np.where((df['grossProfitMargin'].isna()) & df['Revenue'] !=0,(df['Gross Profit']/df['Revenue']) ,df['grossProfitMargin'])

# %%
df['grossProfitMargin'].isnull().sum()/len(df)*100
# Out:
# 10.096480500067944

# %%
df['operatingProfitMargin'].value_counts()
# Out:
# 1.0    19215
# Name: operatingProfitMargin, dtype: int64

# %%
df = df.drop('operatingProfitMargin',1)

# %%
df['effectiveTaxRate'] = np.where((df['effectiveTaxRate'].isna()) & df['Earnings before Tax']!=0,(df['Income Tax Expense']/df['Earnings before Tax']) ,df['effectiveTaxRate'])

# %%
df['effectiveTaxRate'].isnull().sum()/len(df)*100
# Out:
# 7.211124699913937

# %%
df = df.drop('netProfitMargin',1)

# %%
df['eBTperEBIT'] = np.where((df['eBTperEBIT'].isna()) & df['EBIT']!=0,(df['Earnings before Tax']/df['EBIT']) ,df['eBTperEBIT'])

# %%
df['eBTperEBIT'].isnull().sum()/len(df)*100
# Out:
# 8.311817728858088

# %%
df['eBITperRevenue'] = np.where((df['eBITperRevenue'].isna()) & df['Revenue']!=0 ,(df['EBIT']/df['Revenue']) ,df['eBITperRevenue'])

# %%
df['eBITperRevenue'].isnull().sum()/len(df)*100
# Out:
# 10.137246908547356

# %%
df['currentRatio'] = np.where((df['currentRatio'].isna()) & df['Total current assets'] !=0,(df['Total current liabilities']/df['Total current assets']) ,df['currentRatio'])

# %%
df['currentRatio'].isnull().sum()/len(df)*100
# Out:
# 11.781492050550346

# %%
df['debtRatio'] = np.where((df['debtRatio'].isna()) & df['Total current liabilities'] !=0 ,(df['Total current assets']/df['Total current liabilities']) ,df['debtRatio'])

# %%
df['debtRatio'].isnull().sum()/len(df)*100
# Out:
# 7.632377587534537

# %%
df['debtEquityRatio'] = np.where((df['debtEquityRatio'].isna()) & df['Total shareholders equity']!=0 ,(df['Total debt']/df['Total shareholders equity']) ,df['debtEquityRatio'])

# %%
df['debtEquityRatio'].isnull().sum()/len(df)*100
# Out:
# 7.455723150790415

# %%
df = df.drop('operatingCycle',1)

# %%
df = df.drop('cashConversionCycle',1)

# %%
df['debtEquityRatio'] = np.where((df['debtEquityRatio'].isna()) & df['Total shareholders equity']!=0 ,(df['Total debt']/df['Total shareholders equity']) ,df['debtEquityRatio'])

# %%
df['debtEquityRatio'].isnull().sum()/len(df)*100
# Out:
# 7.455723150790415

# %%
df['interestCoverage'] = np.where((df['interestCoverage'].isna()) & df['Interest Expense'] !=0,(df['EBIT']/df['Interest Expense']) ,df['interestCoverage'])

# %%
df['interestCoverage'].isnull().sum()/len(df)*100
# Out:
# 8.17140009965122

# %%
df['companyEquityMultiplier'] = np.where((df['companyEquityMultiplier'].isna()) & df['Total shareholders equity']!=0,(df['Total assets']/df['Total shareholders equity']) ,df['companyEquityMultiplier'])

# %%
df['companyEquityMultiplier'].isnull().sum()/len(df)*100
# Out:
# 6.463740544458033

# %%
df[['Dividend Yield','dividendYield']].isnull().sum()
# Out:
# Dividend Yield    2246
# dividendYield     3298
# dtype: int64

# %%
df = df.drop('Net Income Com',1)

# %%
df = df.drop('dividendYield',1)

# %%
df['freeCashFlowOperatingCashFlowRatio'] = np.where((df['freeCashFlowOperatingCashFlowRatio'].isna()) & df['Operating Cash Flow']!=0,(df['Free Cash Flow']/df['Operating Cash Flow']) ,df['freeCashFlowOperatingCashFlowRatio'])

# %%
df['freeCashFlowOperatingCashFlowRatio'].isna().sum()/len(df)
# Out:
# 0.05983602844589392

# %%
df['cashFlowCoverageRatios'] = np.where((df['cashFlowCoverageRatios'].isna()) & df['Total debt']!=0,(df['Operating Cash Flow']/df['Total debt']) ,df['cashFlowCoverageRatios'])

# %%
df['cashFlowCoverageRatios'].isna().sum()/len(df)*100
# Out:
# 22.675182316437922

# %%
df['dividendPayoutRatio'] = np.where((df['dividendPayoutRatio'].isna()) & df['EPS']!=0,(df['Dividend per Share']/(df['EPS'])) ,df['dividendPayoutRatio'])

# %%
 df['dividendPayoutRatio'].isna().sum()/len(df)*100
# Out:
# 10.617384608415998

# %%
df['Price to Sales Ratio'] = np.where((df['Price to Sales Ratio'].isna()) & df['Revenue']!=0,(df['Market Cap']/(df['Revenue'])) ,df['Price to Sales Ratio'])

# %%
df['Price to Sales Ratio'].isna().sum()/len(df)*100
# Out:
# 10.114598903836573

# %%
df['EV to Sales'] = np.where((df['EV to Sales'].isna()) & df['Revenue']!=0,(df['Enterprise Value']/(df['Revenue'])) ,df['EV to Sales'])

# %%
df['EV to Sales'].isna().sum()/len(df)*100
# Out:
# 22.833718349413417

# %%
df['Enterprise Value over EBITDA'] = np.where((df['Enterprise Value over EBITDA'].isna()) & df['EBITDA']!=0 ,(df['Enterprise Value']/(df['EBITDA'])) ,df['Enterprise Value over EBITDA'])

# %%
df['Enterprise Value over EBITDA'].isna().sum()/len(df)*100
# Out:
# 22.84277755129773

# %%
df['EV to Operating cash flow'] = np.where((df['EV to Operating cash flow'].isna()) & df['Operating Cash Flow']!=0,(df['Enterprise Value']/(df['Operating Cash Flow'])) ,df['EV to Operating cash flow'])

# %%
df['EV to Operating cash flow'].isna().sum()/len(df)*100
# Out:
# 22.833718349413417

# %%
df['EV to Free cash flow'] = np.where((df['EV to Free cash flow'].isna()) & df['Free Cash Flow']!=0 ,(df['Enterprise Value']/(df['Free Cash Flow'])) ,df['EV to Free cash flow'])

# %%
df['EV to Free cash flow'].isna().sum()/len(df)*100
# Out:
# 22.84277755129773

# %%
df['Earnings Yield'] = np.where((df['Earnings Yield'].isna()) &df['Enterprise Value']!=0,(df['EBIT']/df['Enterprise Value']) ,df['Earnings Yield'])

# %%
df['Earnings Yield'].isnull().sum()/len(df)*100
# Out:
# 10.17801331702677

# %%
df['Free Cash Flow Yield'] = np.where((df['Free Cash Flow Yield'].isna()) &df['Market Cap']!=0,(df['Free Cash Flow']/df['Market Cap']) ,df['Free Cash Flow Yield'])

# %%
df['Free Cash Flow Yield'].isnull().sum()/len(df)*100
# Out:
# 14.000996512207276

# %%
df = df.drop('Debt to Equity',1)

# %%
df['Debt to Assets'] = np.where((df['Debt to Assets'].isna()) &df['Total shareholders equity']!=0,(df['Total assets']/df['Total shareholders equity']) ,df['Debt to Assets'])

# %%
df['Debt to Assets'].isnull().sum()/len(df)*100
# Out:
# 6.418444535036463

# %%
df['Net Debt to EBITDA'] = np.where((df['Net Debt to EBITDA'].isna()) & df['EBITDA']!=0,(df['Net Debt']/df['EBITDA']) ,df['Net Debt to EBITDA'])

# %%
df['Net Debt to EBITDA'].isnull().sum()/len(df)*100
# Out:
# 32.400235539248996

# %%
df['Net Income'].value_counts()
# Out:
#  0.000000e+00    43
#  6.000000e+06    15
#  1.000000e+06    13
#  5.000000e+06    13
# -1.000000e+06    12
#                  ..
# -7.808067e+06     1
#  4.961300e+07     1
#  5.589290e+08     1
# -3.545800e+07     1
#  6.380000e+08     1
# Name: Net Income, Length: 19073, dtype: int64

# %%
df = df.drop('Current ratio',1)

# %%
df = df.drop('Interest Coverage',1)

# %%
df['Income Quality'] = np.where((df['Income Quality'].isna()) &df['Net Income']!=0,(df['Operating Cash Flow']/df['Net Income']) ,df['Income Quality'])

# %%
df['Income Quality'].isnull().sum()/len(df)*100
# Out:
# 7.52366716492277

# %%
df = df.drop('Dividend Yield',1)

# %%
df = df.drop('Payout Ratio',1)

# %%
df['SG&A to Revenue'] = np.where((df['SG&A to Revenue'].isna()) &df['Revenue']!=0,(df['SG&A Expense']/df['Revenue']) ,df['SG&A to Revenue'])

# %%
df['SG&A to Revenue'].isnull().sum()/len(df)*100
# Out:
# 7.655025592245323

# %%
df['R&D to Revenue'] = np.where((df['R&D to Revenue'].isna()) & df['Revenue']!=0,(df['R&D Expenses']/df['Revenue']) ,df['R&D to Revenue'])

# %%
df['R&D to Revenue'].isnull().sum()/len(df)*100
# Out:
# 9.688816415273815

# %%
df['Intangibles to Total Assets'] = np.where((df['Intangibles to Total Assets'].isna()) &df['Total assets']!=0  ,(df['Intangibles to Total Assets']/df['Total assets']) ,df['Intangibles to Total Assets'])

# %%
df['Intangibles to Total Assets'].isnull().sum()/len(df)*100
# Out:
# 9.95153326991892

# %%
df['Capex to Operating Cash Flow'] = np.where((df['Capex to Operating Cash Flow'].isna()) & df['Operating Cash Flow']!=0 ,(df['Capital Expenditure']/df['Operating Cash Flow']) ,df['Capex to Operating Cash Flow'])

# %%
df['Capex to Operating Cash Flow'].isnull().sum()/len(df)*100
# Out:
# 7.238302305566879

# %%
df['Capex to Revenue'] = np.where((df['Capex to Revenue'].isna()) & df['Revenue']!=0,(df['Capital Expenditure']/df['Revenue']) ,df['Capex to Revenue'])

# %%
df['Capex to Revenue'].isna().sum()/len(df)*100
# Out:
# 7.668614395071795

# %%
df['Capex to Depreciation'] = np.where((df['Capex to Depreciation'].isna()) & df['Depreciation & Amortization']!=0,(df['Capital Expenditure']/df['Depreciation & Amortization']) ,df['Capex to Depreciation'])

# %%
df['Capex to Depreciation'].isna().sum()/len(df)*100
# Out:
# 7.818091226162975

# %%
df['Stock-based compensation to Revenue'] = np.where((df['Stock-based compensation to Revenue'].isna()) & df['Revenue']!=0,(df['Stock-based compensation']/df['Revenue']) ,df['Stock-based compensation to Revenue'])

# %%
df['Stock-based compensation to Revenue'].isna().sum()/len(df)*100
# Out:
# 8.647008198577705

# %%
df['Working Capital'] = np.where((df['Working Capital'].isna()) ,(df['Total current assets']-df['Total current liabilities']) ,df['Working Capital'])

# %%
df['Working Capital'].isna().sum()/len(df)*100
# Out:
# 11.56407120532681

# %%
df['Tangible Asset Value'] = np.where((df['Tangible Asset Value'].isna()) ,(df['Total assets']-df['Goodwill and Intangible Assets'] - df['Total liabilities']) ,df['Tangible Asset Value'])

# %%
df['Tangible Asset Value'].isna().sum()/len(df)*100
# Out:
# 6.6132173755492145

# %%
df = df.drop('shortTermCoverageRatios',1)

# %%
x1 = df['2015 PRICE VAR [%]']
x1 = x1.dropna()

# %%
x2 = df['2016 PRICE VAR [%]']
x2 = x2.dropna()

# %%
x3 = df['2017 PRICE VAR [%]']
x3 = x3.dropna()

# %%
x4 = df['2018 PRICE VAR [%]']
x4 = x4.dropna()

# %%
x5 = df['2019 PRICE VAR [%]']
x5 = x5.dropna()

# %%
x = pd.concat([x1,x2,x3,x4,x5])

# %%
df = df.drop(['2015 PRICE VAR [%]','2016 PRICE VAR [%]','2017 PRICE VAR [%]','2018 PRICE VAR [%]','2019 PRICE VAR [%]'],1)

# %%
df.isnull().sum()/len(df)*100
# Out:
# Revenue                                       5.304163
# Revenue Growth                                7.704851
# Cost of Revenue                               8.021923
# Gross Profit                                  5.467228
# R&D Expenses                                  9.684287
# SG&A Expense                                  7.559904
# Operating Expenses                            7.709381
# Operating Income                              4.987091
# Interest Expense                              7.786384
# Earnings before Tax                           6.178376
# Income Tax Expense                            7.193006
# Net Income - Non-Controlling int             10.232369
# Net Income - Discontinued ops                10.232369
# Net Income                                    7.088825
# Preferred Dividends                          10.232369
# EPS                                           5.856774
# EPS Diluted                                   5.852244
# ...

# %%
for i in df.columns:
    print(i)
    print(np.any(np.isinf(df[i])))
# Out:
# Revenue
# False
# Revenue Growth
# False
# Cost of Revenue
# False
# Gross Profit
# False
# R&D Expenses
# False
# SG&A Expense
# False
# Operating Expenses
# False
# Operating Income
# False
# Interest Expense
# False
# Earnings before Tax
# False
# Income Tax Expense
# False
# Net Income - Non-Controlling int
# False
# Net Income - Discontinued ops
# False
# Net Income
# False
# Preferred Dividends
# False
# EPS
# False
# EPS Diluted
# False
# Weighted Average Shs Out
# False
# Weighted Average Shs Out (Dil)
# False
# Dividend per Share
# False
# Gross Margin
# False
# EBITDA Margin
# False
# EBIT Margin
# False
# Profit Margin
# False
# Free Cash Flow margin
# False
# EBITDA
# False
# EBIT
# False
# Consolidated Income
# False
# Earnings Before Tax Margin
# False
# Net Profit Margin
# False
# Cash and cash equivalents
# False
# Short-term investments
# False
# Cash and short-term investments
# False
# Receivables
# False
# Inventories
# False
# Total current assets
# False
# ...

# %%
 df = df.drop('priceToSalesRatio',1)

# %%
df[np.isinf(df['Asset Growth'])]['Asset Growth']
# Out:
# Unnamed: 0
# BRPAU    inf
# INDU     inf
# ECCA     inf
# ECCB     inf
# Name: Asset Growth, dtype: float64

# %%
df = df.drop(['BRPAU','INDU','ECCA','ECCB'],0)

# %%
Sector = sector.drop(['BRPAU','INDU','ECCA','ECCB'],0)

# %%
sector = df['Sector']
df = df.drop('Sector',1)

# %%
df['price var'] = x

# %%
np.sqrt(len(df.columns))
# Out:
# 14.317821063276353

# %%
from sklearn.impute import KNNImputer
knn = KNNImputer(n_neighbors=15)

# %%
x = knn.fit_transform(df)

# %%
df_new = pd.DataFrame(x,columns=df.columns)

# %%
len(df_new),len(Sector)
# Out:
# (22064, 22064)

# %%
df = df.reset_index()
df
# Out:
#       Unnamed: 0       Revenue  Revenue Growth  Cost of Revenue  Gross Profit  \
# 0             PG  7.440100e+10         -0.0713     3.903000e+10  3.537100e+10
# 1           VIPS  3.734148e+09          1.1737     2.805625e+09  9.285226e+08
# 2             KR  9.837500e+10          0.0182     7.813800e+10  2.023700e+10
# 3            RAD  2.552641e+10          0.0053     1.820268e+10  7.323734e+09
# 4            GIS  1.790960e+10          0.0076     1.153980e+10  6.369800e+09
# ...          ...           ...             ...              ...           ...
# 22059       YRIV  0.000000e+00          0.0000     0.000000e+00  0.000000e+00
# 22060       YTEN  5.560000e+05         -0.4110     0.000000e+00  5.560000e+05
# 22061       ZKIN  5.488438e+07          0.2210     3.659379e+07  1.829059e+07
# 22062        ZOM  0.000000e+00          0.0000     0.000000e+00  0.000000e+00
# 22063       ZYME  5.301900e+07          0.0243     0.000000e+00  5.301900e+07
#
# ...

# %%
df_new = df_new.reset_index()

# %%
df_new['Unnamed: 0'] = df['Unnamed: 0']

# %%
Sector = Sector.reset_index()
Sector
# Out:
#        index Unnamed: 0              Sector
# 0          0         PG  Consumer Defensive
# 1          1       VIPS  Consumer Defensive
# 2          2         KR  Consumer Defensive
# 3          3        RAD  Consumer Defensive
# 4          4        GIS  Consumer Defensive
# ...      ...        ...                 ...
# 22059  22059       YRIV         Real Estate
# 22060  22060       YTEN     Basic Materials
# 22061  22061       ZKIN     Basic Materials
# 22062  22062        ZOM         Industrials
# 22063  22063       ZYME          Healthcare
#
# [22064 rows x 3 columns]

# %%
df_new['Sector'] = Sector['Sector']

# %%
df_new
# Out:
#        index       Revenue  Revenue Growth  Cost of Revenue  Gross Profit  \
# 0          0  7.440100e+10         -0.0713     3.903000e+10  3.537100e+10
# 1          1  3.734148e+09          1.1737     2.805625e+09  9.285226e+08
# 2          2  9.837500e+10          0.0182     7.813800e+10  2.023700e+10
# 3          3  2.552641e+10          0.0053     1.820268e+10  7.323734e+09
# 4          4  1.790960e+10          0.0076     1.153980e+10  6.369800e+09
# ...      ...           ...             ...              ...           ...
# 22059  22059  0.000000e+00          0.0000     0.000000e+00  0.000000e+00
# 22060  22060  5.560000e+05         -0.4110     0.000000e+00  5.560000e+05
# 22061  22061  5.488438e+07          0.2210     3.659379e+07  1.829059e+07
# 22062  22062  0.000000e+00          0.0000     0.000000e+00  0.000000e+00
# 22063  22063  5.301900e+07          0.0243     0.000000e+00  5.301900e+07
#
#        R&D Expenses  SG&A Expense  Operating Expenses  Operating Income  \
# ...

# %%
df_new.to_excel('project_till_knn.xlsx')
